# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnavekariya1995/Data-Analytics-Internship-Tasks/blob/main/Task_4_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
data = {
    "review": [
        "The product is amazing and works perfectly",
        "Very bad experience, totally disappointed",
        "Average quality, nothing special",
        "Excellent service and fast delivery",
        "Worst purchase ever"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                        review
# 0  The product is amazing and works perfectly
# 1   Very bad experience, totally disappointed
# 2            Average quality, nothing special
# 3         Excellent service and fast delivery
# 4                         Worst purchase ever

# %%
sia = SentimentIntensityAnalyzer()

# %%
df["sentiment_score"] = df["review"].apply(lambda x: sia.polarity_scores(x)["compound"])

# %%
def get_sentiment(score):
    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

df["sentiment"] = df["sentiment_score"].apply(get_sentiment)
df
# Out:
#                                        review  sentiment_score sentiment
# 0  The product is amazing and works perfectly           0.8402  Positive
# 1   Very bad experience, totally disappointed          -0.8012  Negative
# 2            Average quality, nothing special          -0.3089  Negative
# 3         Excellent service and fast delivery           0.5719  Positive
# 4                         Worst purchase ever          -0.6249  Negative

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# Negative    3
# Positive    2
# Name: count, dtype: int64

# %% [markdown]
# ## Task 4 – Sentiment Analysis
#
# Sentiment analysis was performed on textual review data using Natural Language
# Processing techniques. The VADER sentiment analyzer was used to calculate
# sentiment scores and classify reviews as Positive, Negative, or Neutral.
# The results provide insights into customer opinions and overall sentiment trends.

# %% [markdown]
# ### Key Insights
# - Positive reviews show high sentiment scores indicating customer satisfaction.
# - Negative reviews highlight dissatisfaction and poor experience.
# - Sentiment classification helps understand overall customer perception.
